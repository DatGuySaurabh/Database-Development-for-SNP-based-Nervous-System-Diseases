# %%
import pandas as pd
import matplotlib as plt

# %%
data = pd.read_csv('NDPUVdataset.csv')
data
#data.columns.tolist()
# Out:
#        GRCh38Chromosome  GRCh38Location Referance allele Alternate Allele  \
# 0                     X       153725570                G                A
# 1                     X       153725604                G                A
# 2                     X       153726087                G                A
# 3                     X       153726095                G                T
# 4                     X       153726168                T                C
# ...                 ...             ...              ...              ...
# 212721               10        15397986                G                G
# 212722                2        41568252                C                T
# 212723                8       120151523                C                A
# 212724               11        55611694                C                T
# 212725               19        16676994                C                T
#
#                    Condition
# 0       Adrenoleukodystrophy
# ...

# %%
data.sample(n=10)
# Out:
#        GRCh38Chromosome  GRCh38Location Referance allele Alternate Allele  \
# 105928                9       114019179                A                A
# 56885                 4        80202867                G                A
# 15195                 1        10376529                C                T
# 182213                1       210682983                T                T
# 35624                 X        32438326                G                A
# 46796                15        26772924                G                A
# 72683                17        31156000                A                T
# 67383                 X        78020278                C                T
# 176342                9        89504779                G                A
# 3616                  9        34635601                T                C
#
#                             Condition
# 105928                  Nonpathogenic
# 56885                        Epilepsy
# ...

# %%
#data = data.drop_duplicates(keep='first')

# %%
data.value_counts()
# Out:
# GRCh38Chromosome  GRCh38Location  Referance allele  Alternate Allele  Condition
# 1                 62124           G                 A                 Nonpathogenic          1
# 4                 122923217       C                 T                 Epilepsy               1
#                   122923143       A                 G                 Epilepsy               1
#                                                     T                 Epilepsy               1
#                   122923144       T                 C                 Epilepsy               1
#                                                                                             ..
# 16                2088515         C                 G                 Tuberous sclerosis     1
#                                                     T                 Tuberous sclerosis     1
#                   2088516         C                 G                 Tuberous sclerosis     1
# ...

# %%
#data.to_csv('dataset.csv',index=False)
data.duplicated()
data.duplicated().sum()
# Out:
# 0

# %%
data["Condition"]
# Out:
# 0         Adrenoleukodystrophy
# 1         Adrenoleukodystrophy
# 2         Adrenoleukodystrophy
# 3         Adrenoleukodystrophy
# 4         Adrenoleukodystrophy
#                   ...
# 212721           Nonpathogenic
# 212722           Nonpathogenic
# 212723           Nonpathogenic
# 212724           Nonpathogenic
# 212725           Nonpathogenic
# Name: Condition, Length: 212726, dtype: object

# %%
data["Condition"].unique()
# Out:
# array(['Adrenoleukodystrophy', 'Alzheimer Disease',
#        'Amyotrophic lateral sclerosis', 'Angelman syndrome',
#        'Ataxia telangiectasia', 'Charcot-Marie-Tooth Disease',
#        'Cockayne syndrome', 'Cohen syndrome', 'Deafness',
#        'Duchenne muscular dystrophy', 'Epilepsy', 'Fragile X Syndrome',
#        'Maple syrup urine Disease', 'Menkes kinky-hair syndrome',
#        'Mental retardation', 'Microcephaly', 'Narcolepsy',
#        'Neurofibromatosis', 'Niemann-Pick Disease ', 'Parkinson Disease',
#        'Phenylketonuria', 'Rett syndrome', 'Spinal Muscular Atrophy',
#        'Spinocerebellar ataxia ', 'Tuberous sclerosis ',
#        'Von Hippel-Lindau syndrome', 'Wilson Disease',
#        'Zellweger syndrome', 'Nonpathogenic'], dtype=object)

# %%
graph = data["Condition"].value_counts()
graph
# Out:
# Nonpathogenic                    109989
# Epilepsy                          28796
# Deafness                          12319
# Charcot-Marie-Tooth Disease        7033
# Ataxia telangiectasia              7028
# Tuberous sclerosis                 6943
# Neurofibromatosis                  5983
# Spinal Muscular Atrophy            4889
# Spinocerebellar ataxia             4817
# Amyotrophic lateral sclerosis      3226
# Zellweger syndrome                 2899
# Duchenne muscular dystrophy        2792
# Parkinson Disease                  2351
# Cohen syndrome                     1721
# Microcephaly                       1470
# Maple syrup urine Disease          1041
# Niemann-Pick Disease               1027
# Von Hippel-Lindau syndrome          929
# Wilson Disease                      869
# Alzheimer Disease                   832
# Phenylketonuria                     811
# Rett syndrome                       761
# Cockayne syndrome                   744
# ...

# %%
rett = data[(data["Condition"]=="Rett syndrome")]
rett
#rett.info()
# Out:
#       GRCh38Chromosome  GRCh38Location Referance allele Alternate Allele  \
# 80630                X        18598551                T                C
# 80631                X        18507155                G                T
# 80632                X        18653483                C                T
# 80633                X        18588037                G                A
# 80634                X        18604158                A                G
# ...                ...             ...              ...              ...
# 81386                9       127675855                C                T
# 81387                9       127660034                T                A
# 81388                9       127676722                T                G
# 81389                9       127663314                G                A
# 81390                9       127682489                G                A
#
#            Condition
# 80630  Rett syndrome
# 80631  Rett syndrome
# 80632  Rett syndrome
# ...

# %%
#data.rename(columns = {"Condition(s)":"Condition"}, inplace = True)
#li = ['Tay-Sachs Disease','Mowat-Wilson syndrome','Tangier Disease','Gaucher Disease','Hyperekplexia ','Chondrocalcinosis ','Hereditary essential tremor','Baraitser-Winter syndrome ',' Williams Syndrome','Bartter Disease','Lesch-Nyhan syndrome','Refsum Disease',' Paget Disease','Huntington Disease']
#datanew = data[data.Condition.isin(li) == False]

# %%
#datanew["Condition"].value_counts()
# Out:
# Nonpathogenic                    109989
# Epilepsy                          28796
# Deafness                          12319
# Charcot-Marie-Tooth Disease        7033
# Ataxia telangiectasia              7028
# Tuberous sclerosis                 6943
# Neurofibromatosis                  5983
# Spinal Muscular Atrophy            4889
# Spinocerebellar ataxia             4817
# Amyotrophic lateral sclerosis      3226
# Zellweger syndrome                 2899
# Duchenne muscular dystrophy        2792
# Parkinson Disease                  2351
# Cohen syndrome                     1721
# Microcephaly                       1470
# Maple syrup urine Disease          1041
# Niemann-Pick Disease               1027
# Von Hippel-Lindau syndrome          929
# Wilson Disease                      869
# Alzheimer Disease                   832
# Phenylketonuria                     811
# Rett syndrome                       761
# Cockayne syndrome                   744
# ...

# %%
#datanew
# Out:
#        GRCh38Chromosome  GRCh38Location Referance allele Alternate Allele  \
# 0                     X       153725570                G                A
# 1                     X       153725604                G                A
# 2                     X       153726087                G                A
# 3                     X       153726095                G                T
# 4                     X       153726168                T                C
# ...                 ...             ...              ...              ...
# 214832               10        15397986                G                G
# 214833                2        41568252                C                T
# 214834                8       120151523                C                A
# 214835               11        55611694                C                T
# 214836               19        16676994                C                T
#
#                    Condition
# 0       Adrenoleukodystrophy
# ...

# %%
graph = data["Condition"].value_counts()
graph.plot.bar()
# Out:
# <AxesSubplot: >

# %%
datanew
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25260\1278388311.py in <module>
# ----> 1 datanew
#
# NameError: name 'datanew' is not defined

# %%
ND = pd.read_csv("NDPUVdataset.csv")

# %%
ND["GRCh38Location"].duplicated().sum()
# Out:
# 11336

# %%
sma.drop(sma[sma['Referance allele'] == "CC"].index, inplace = True)
sma.drop(sma[sma['Referance allele'] == "CT"].index, inplace = True)
sma.drop(sma[sma['Referance allele'] == "AT"].index, inplace = True)
sma.drop(sma[sma['Referance allele'] == "GG"].index, inplace = True)
sma.drop(sma[sma['Referance allele'] == "TTT"].index, inplace = True)
sma.drop(sma[sma['Alternate Allele'] == "TT"].index, inplace = True)
sma.drop(sma[sma['Alternate Allele'] == "CC"].index, inplace = True)
sma.drop(sma[sma['Alternate Allele'] == "AA"].index, inplace = True)
sma.drop(sma[sma['Alternate Allele'] == "AC"].index, inplace = True)
sma.drop(sma[sma['Alternate Allele'] == "AT"].index, inplace = True)
sma.drop(sma[sma['Alternate Allele'] == "GC"].index, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25260\274085540.py in <module>
# ----> 1 sma.drop(sma[sma['Referance allele'] == "CC"].index, inplace = True)
#       2 sma.drop(sma[sma['Referance allele'] == "CT"].index, inplace = True)
#       3 sma.drop(sma[sma['Referance allele'] == "AT"].index, inplace = True)
#       4 sma.drop(sma[sma['Referance allele'] == "GG"].index, inplace = True)
#       5 sma.drop(sma[sma['Referance allele'] == "TTT"].index, inplace = True)
#
# NameError: name 'sma' is not defined

# %%
dup = pd.concat(g for _, g in ND.groupby("GRCh38Location") if len(g) > 1)
dup
# Out:
#       GRCh38Chromosome  GRCh38Location Referance allele Alternate Allele  \
# 49935               16           88899                G                C
# 54876               16           88899                G                T
# 50058               16           89786                G                A
# 50115               16           89786                G                C
# 50068               16           93226                C                T
# ...                ...             ...              ...              ...
# 86678                1       226982111                G                T
# 12463                1       228097624                A                G
# 12464                1       228097624                A                C
# 29974                1       247418268                C                T
# 29975                1       247418268                C                G
#
#                          Condition
# 49935                     Epilepsy
# ...

# %%
ND.duplicated().sum()
# Out:
# 0

# %%
a=11336*2
a
# Out:
# 22672

# %%
n=ND.tail(109989)

# %%
p = ND.head(102737)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(12,6))
res = sns.kdeplot(p["GRCh38Location"] , color='crimson', label='Pathogenic', fill=True )
res= sns.kdeplot(n["GRCh38Location"] , color='limegreen', label='Nonpathogenic', fill=True )
ax.legend()
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(12,6))
res = sns.histplot(p["GRCh38Location"] , color='crimson', label='Pathogenic', fill=True , kde=True )
res= sns.histplot(n["GRCh38Location"] , color='limegreen', label='Nonpathogenic', fill=True, kde=True )
ax.legend()
plt.tight_layout()
plt.show()

# %%
sns.histplot(p["GRCh38Chromosome"])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(12,6))
res = sns.kdeplot(p["GRCh38Location"] , color='crimson', label='Pathogenic', fill=True )
res= sns.kdeplot(n["GRCh38Location"] , color='limegreen', label='Nonpathogenic', fill=True )
ax.legend()
plt.tight_layout()
plt.ticklabel_format(style="plain",axis='x')
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.title("Scatter Plot for Pathogenic")
plt.ticklabel_format(style="plain",axis='y')
sns.stripplot(p["GRCh38Location"])
# Out:
# <AxesSubplot: title={'center': 'Scatter Plot for Pathogenic'}, ylabel='GRCh38Location'>

# %%
plt.figure(figsize=(15,15))
plt.title("Scatter Plot for NonPathogenic")
plt.ticklabel_format(style="plain",axis='y')
sns.stripplot(n["GRCh38Location"])
# Out:
# <AxesSubplot: title={'center': 'Scatter Plot for NonPathogenic'}, ylabel='GRCh38Location'>

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19284\391604064.py in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
data
# Out:
#        GRCh38Chromosome  GRCh38Location Referance allele Alternate Allele  \
# 0                     X       153725570                G                A
# 1                     X       153725604                G                A
# 2                     X       153726087                G                A
# 3                     X       153726095                G                T
# 4                     X       153726168                T                C
# ...                 ...             ...              ...              ...
# 212721               10        15397986                G                G
# 212722                2        41568252                C                T
# 212723                8       120151523                C                A
# 212724               11        55611694                C                T
# 212725               19        16676994                C                T
#
#                    Condition
# 0       Adrenoleukodystrophy
# ...

# %%
pathogenic = pd.data[]

# %%
categ = ['GRCh38Chromosome','Referance allele','Alternate Allele','Condition']

# Encode Categorical Columns
le = preprocessing.LabelEncoder()
p[categ] = p[categ].apply(le.fit_transform)

# %%
#removing all "-" characters
data = data.loc[data["Alternate Allele"] != "-"]
data = data.loc[data["Referance allele"] != "-"]

# %%
import pandas as pd
a = pd.read_csv("NDPUV_dataset.csv")

# %%
sma = a

# %%
a["Referance Allele"].value_counts()
# Out:
# C    56574
# G    55864
# A    29877
# T    29236
# Name: Referance Allele, dtype: int64

# %%
sma.drop(sma[sma['Referance Allele'] == "CC"].index, inplace = True)
sma.drop(sma[sma['Referance Allele'] == "GG"].index, inplace = True)
sma.drop(sma[sma['Referance Allele'] == "AA"].index, inplace = True)
sma.drop(sma[sma['Referance Allele'] == "TT"].index, inplace = True)

# %%
sma
# Out:
#        GRCh38Chromosome  GRCh38Location Referance Allele Alternate Allele  \
# 0                     X       153725570                G                A
# 1                     X       153725604                G                A
# 2                     X       153726087                G                A
# 3                     X       153726095                G                T
# 4                     X       153726168                T                C
# ...                 ...             ...              ...              ...
# 171552                2       144513777                T                C
# 171553                2       144520255                T                C
# 171554                2       144520274                A                T
# 171555                2       144520823                A                C
# 171556                2       144520899                A                C
#
#                    Condition
# 0       Adrenoleukodystrophy
# ...

# %%
sma["GRCh38Chromosome"].value_counts()
# Out:
# 11    14795
# 16    13615
# 9     12233
# 2     12170
# 17    11913
# 1     10719
# 6     10102
# 14     9700
# X      9401
# 8      8177
# 10     7701
# 7      6729
# 12     6047
# 19     5976
# 5      5676
# 20     5462
# 3      4739
# 22     3821
# 15     3373
# 18     2601
# 21     2371
# 4      2133
# 13     2096
# Y         1
# Name: GRCh38Chromosome, dtype: int64

# %%
data = sma.loc[sma["GRCh38Chromosome"] != "Y"]

# %%
data
# Out:
#        GRCh38Chromosome  GRCh38Location Referance Allele Alternate Allele  \
# 0                     X       153725570                G                A
# 1                     X       153725604                G                A
# 2                     X       153726087                G                A
# 3                     X       153726095                G                T
# 4                     X       153726168                T                C
# ...                 ...             ...              ...              ...
# 171552                2       144513777                T                C
# 171553                2       144520255                T                C
# 171554                2       144520274                A                T
# 171555                2       144520823                A                C
# 171556                2       144520899                A                C
#
#                    Condition
# 0       Adrenoleukodystrophy
# ...

# %%
# data.to_csv("NDPUV_dataset.csv",index=False)

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn import preprocessing

a= pd.read_csv("NDPUV_dataset.csv")

# %%
from sklearn.model_selection import StratifiedKFold

# %%
categ = ['GRCh38Chromosome','Referance Allele','Alternate Allele','Condition']

# Encode Categorical Columns
le = preprocessing.LabelEncoder()
a[categ] = a[categ].apply(le.fit_transform)

# %%
from sklearn.model_selection import train_test_split

y = a.Condition
pns_f=["GRCh38Chromosome",	"GRCh38Location",	"Referance Allele","Alternate Allele"]
x=a[pns_f]
#train_x, val_x, train_y, val_y = train_test_split(x , y, random_state=0)

# %%
# from sklearn.model_selection import GridSearchCV
# rf_model = RandomForestClassifier()
# param_grid = {
#     'bootstrap': [True],
#     'max_depth': [80, 90, 100, 110],
#     'max_features': [2, 3, 4],
#     'min_samples_leaf': [3, 4, 5],
#     'min_samples_split': [8, 10, 12],
#     'n_estimators': [100, 200, 300, 1000]
# }
# grid_search = GridSearchCV(estimator = rf_model, param_grid = param_grid, 
#                           cv =2, n_jobs = 4, verbose = 10)

# grid_search.fit(train_x, train_y)
# grid_search.best_params_
# Out:
# Fitting 2 folds for each of 432 candidates, totalling 864 fits

# %%
# dt = RandomForestClassifier()
# skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=1)
# lst_accu_stratified = []
  
# for train_index, test_index in skf.split(x, y):
#     x_train_fold, x_test_fold = x[train_index], y[test_index]
#     y_train_fold, y_test_fold = y[train_index], y[test_index]
#     dt.fit(x_train_fold, y_train_fold)
#     lst_accu_stratified.append(dt.score(x_test_fold, y_test_fold))
  
# # Print the output.
# print('List of possible accuracy:', lst_accu_stratified)
# print('\nMaximum Accuracy That can be obtained from this model is:',
#       max(lst_accu_stratified)*100, '%')
# print('\nMinimum Accuracy:',
#       min(lst_accu_stratified)*100, '%')
# #print('\nOverall Accuracy:',
#       #mean(lst_accu_stratified)*100, '%')
# #print('\nStandard Deviation is:', stdev(lst_accu_stratified))

# %%
NDPUV = pd.read_csv("NDPUVpathogenic.csv")
NDPUV
# Out:
#        GRCh38Chromosome  GRCh38Location Referance Allele Alternate Allele  \
# 0                     X       153725570                G                A
# 1                     X       153725604                G                A
# 2                     X       153726087                G                A
# 3                     X       153726095                G                T
# 4                     X       153726168                T                C
# ...                 ...             ...              ...              ...
# 102732                6        42968289                C                T
# 102733                6        42974002                C                T
# 102734                1         2412502                T                C
# 102735                1         2405321                C                T
# 102736                1         2405090                G                A
#
#                    Condition
# 0       Adrenoleukodystrophy
# ...

# %%
ZSNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/Zellewgwer Syndrome/Zellewgwer Syndrome.csv")
WNDNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/Wilson Disease/Wilson Disease.csv")
WSDNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/Williams Disease/Williams Disease.csv")
VHLSNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/VHLS/VHLS.csv")
TSNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/Tuberous Sclerosis/Tuberous Sclerosis.csv")
TSDNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/TSD/TSD.csv")
TDNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/Tangier Disease/Tangier disease.csv")
SANP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/Spino Ataxia/Spino Ataxia.csv")
SMANP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/SMA/SMA.csv")
RSNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/Rett Syndrome/Rett Syndrome.csv")
RFSNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/Refsum Syndrome/Refsum Syndrome.csv")
PWSNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/PWS/PWS.csv")
PKUNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/PKU/PKU.csv")
PDNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/Parkinson Disease/Parkinson Disease.csv")
NPDTNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/NPDT/NPDT.csv")
NFNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/Neurofibromatosis/Neurofibromatosis.csv")
NCNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/Narcolepsy/Narcolepsy.csv")
MSNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/Menkes Syndrome/Menkes Syndrome.csv")
MSUNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/MSUD/MSUD.csv")
LNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/Lesch/Lesch.csv")
GDNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/Gaucher Disease/Gaucher Disease.csv")
FXSNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/FXS/FXS.csv")
EPNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/Epilepsy/Epilepsy.csv")
DMDNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/DMD/DMD.csv")
DNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/Deafness/Deafness.csv")
CKNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/Cockayne/Cockayne.csv")
CMTNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/CMT/CMT.csv")
ATNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/Ataxia/Ataxia.csv")
AMNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/Angelman/Angelman.csv")
AZNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/Alzheimers/Alzheimers.csv")
ALSNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/ALS/ALS.csv")
ADRNP = pd.read_csv("/OneDrive - International Institute of Information Technology/NDPUV DATA/Gene_SNP/ADR/ADR.csv")

# %%
RSP = NDPUV[(NDPUV["Condition"]=="Rett syndrome")]

# %%
NDPUV["Condition"].value_counts()
# Out:
# Epilepsy                         28796
# Deafness                         12319
# Charcot-Marie-Tooth Disease       7033
# Ataxia telangiectasia             7028
# Tuberous sclerosis                6943
# Neurofibromatosis                 5983
# Spinal Muscular Atrophy           4889
# Spinocerebellar ataxia            4817
# Amyotrophic lateral sclerosis     3226
# Zellweger syndrome                2899
# Duchenne muscular dystrophy       2792
# Parkinson Disease                 2351
# Cohen syndrome                    1721
# Microcephaly                      1470
# Maple syrup urine Disease         1041
# Niemann-Pick Disease              1027
# Von Hippel-Lindau syndrome         929
# Wilson Disease                     869
# Alzheimer Disease                  832
# Phenylketonuria                    811
# Rett syndrome                      761
# Cockayne syndrome                  744
# Angelman syndrome                  705
# Mental retardation                 657
# ...

# %%
ZSP = NDPUV[(NDPUV["Condition"]=="Zelleweger Syndrome")]
WSDP = NDPUV[(NDPUV["Condition"]=="Wilson Disease")] 
VHLSP = NDPUV[(NDPUV["Condition"]=="Von Hippel-Lindau syndrome")]
TSP  = NDPUV[(NDPUV["Condition"]=="Tuberous sclerosis ")]
SAP  = NDPUV[(NDPUV["Condition"]=="Spinocerebellar ataxia ")]
SMAP  = NDPUV[(NDPUV["Condition"]=="Spinal Muscular Atrophy")]
RSP  = NDPUV[(NDPUV["Condition"]=="Rett syndrome")]
PKUP  = NDPUV[(NDPUV["Condition"]=="Phenylketonuria")]
PDP  = NDPUV[(NDPUV["Condition"]=="Parkinson Disease")]
NPDTP  = NDPUV[(NDPUV["Condition"]=="Niemann-Pick Disease ")]
NFP  = NDPUV[(NDPUV["Condition"]=="Neurofibromatosis")]
NCP  = NDPUV[(NDPUV["Condition"]=="Narcolepsy")]
MSP  = NDPUV[(NDPUV["Condition"]=="Menkes kinky-hair syndrome")]
MSUP  = NDPUV[(NDPUV["Condition"]=="Maple syrup urine Disease")]
FXSP  = NDPUV[(NDPUV["Condition"]=="Fragile X Syndrome")]
EPP  = NDPUV[(NDPUV["Condition"]=="Epilepsy")]
DMDP  = NDPUV[(NDPUV["Condition"]=="Duchenne muscular dystrophy")]
DP = NDPUV[(NDPUV["Condition"]=="Deafness")]
CKP  = NDPUV[(NDPUV["Condition"]=="Cockayne syndrome")]
CMTP  = NDPUV[(NDPUV["Condition"]=="Charcot-Marie-Tooth Disease")]
ATP  = NDPUV[(NDPUV["Condition"]=="Ataxia telangiectasia")]
AMP  = NDPUV[(NDPUV["Condition"]=="Angelman syndrome")]
AZP  = NDPUV[(NDPUV["Condition"]=="Alzheimer Disease")]
ALSP  = NDPUV[(NDPUV["Condition"]=="Amyotrophic lateral sclerosis")]
ADRP  = NDPUV[(NDPUV["Condition"]=="Adrenoleukodystrophy")]

# %%
ADRNP
# Out:
#      #chr        pos variation                gene
# 0       X  153740449       C>T  ABCD1;LOC124905226
# 1       X  153740295       C>T  ABCD1;LOC124905226
# 2       X  153741041       A>C  ABCD1;LOC124905226
# 3       X  153740151       G>A  ABCD1;LOC124905226
# 4       X  153736544       C>T  ABCD1;LOC124905226
# ...   ...        ...       ...                 ...
# 3104    6   42966421       C>T                PEX6
# 3105    6   42968478       A>G                PEX6
# 3106    6   42978614       C>G                PEX6
# 3107    6   42978650       A>G                PEX6
# 3108    6   42979097       C>T                PEX6
#
# [3109 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
SMANP["#chr"].unique()
# Out:
# array(['8', '#chr', '9', '2', '5', '19', '1'], dtype=object)

# %%
SMAP["GRCh38Chromosome"].unique()
# Out:
# array(['16', '1', 'X', '8', '10', '4', '9', '11', '19', '15', '22', '17',
#        '2', '6', '14', '5', '13', '7', '12', '3', '20'], dtype=object)

# %%
plt.figure(figsize=(5,5))
plt.title("Scatter Plot for Charcot-Marie-Tooth Disease Pathogenic")
plt.ticklabel_format(useOffset=False,style="plain",axis='y')
sns.stripplot(CMTP["GRCh38Location"])
plt.figure(figsize=(5,5))
plt.title("Scatter Plot for Charcot-Marie-Tooth Disease Non-Pathogenic")
plt.ticklabel_format(useOffset=False,style="plain",axis='y')
sns.stripplot(CMTNP["pos"])
# Out:
# <Axes: title={'center': 'Scatter Plot for Charcot-Marie-Tooth Disease Non-Pathogenic'}, ylabel='pos'>

# %%
plt.figure(figsize=(5,5))
plt.title("Scatter Plot for Pathogenic")
plt.ticklabel_format(useOffset=False,style="plain",axis='y')
sns.stripplot(SMAP["GRCh38Location"])
plt.figure(figsize=(5,5))
plt.title("Scatter Plot for Non-Pathogenic")
plt.ticklabel_format(useOffset=False,style="plain",axis='y')
sns.stripplot(SMANP["pos"])
# Out:
# <Axes: title={'center': 'Scatter Plot for Non-Pathogenic'}, ylabel='pos'>

# %%
plt.figure(figsize=(3,3))
plt.title("Scatter Plot for Pathogenic")
plt.ticklabel_format(style="plain",axis='y')
sns.scatterplot(EPNP["pos"])
sns.scatterplot(EPP["GRCh38Location"], color='crimson')
# Out:
# <Axes: title={'center': 'Scatter Plot for Pathogenic'}, ylabel='pos'>

# %%
fig, ax = plt.subplots(figsize=(15,9))
res = sns.kdeplot(ATP["GRCh38Location"] , color='crimson', label='Pathogenic', fill=True )
res= sns.kdeplot(ATNP["pos"] , color='limegreen', label='Nonpathogenic', fill=True )
ax.legend()
plt.tight_layout()
plt.title("Distribution of Tuberous sclerosis Variants")
plt.ticklabel_format(style="plain",axis='x')
plt.ticklabel_format(style="plain",axis='y')
plt.show()

# %%
# setting up grid for multiple seaborn plots
fig, axes = plt.subplots(1,2,figsize=(10,5))
fig.suptitle('Tuberous Sclerosis Variants\nPathogenic vs Non_Pathogenic')
sns.set_style('whitegrid');
#plt.ticklabel_format(style="plain")
# pathogenic

sns.stripplot(y=TSP.GRCh38Location, linewidth=0.6, jitter= 0.3, ax=axes[0])

#Non-Pathogenic

sns.stripplot(y=TSNP.pos, linewidth=0.6, jitter= 0.3, ax=axes[1])

plt.show()
